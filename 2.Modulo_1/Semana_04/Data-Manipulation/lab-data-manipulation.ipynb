# %% [markdown]
# # Lab-Data-Manipulation (PART-1)

# %%
import pandas as pd

# %% [markdown]
# # Context
#
# For this lab you'll use a dataset for UFO observations. The objective is to exercise the manipulation of a dataframe, so we'll use the tools we've learned about `reading`, `renaming`, `selecting specific columns`, `filtering based on conditions` and `merging` dataframes to try to better understand our dataset and store an enriched version of our dataset at the end.
#
# Good Luck.

# %% [markdown]
# variable	|class|	description
# ------------|-----|-------------
# date_time	|datetime (mdy h:m)	| Date time sighting occurred
# city_area	|character	        | City or area of sighting
# state	    |character          |	state/region of sighting
# country	    |character          |	Country of sighting
# ufo_shape	|character          |	UFO Shape
# encounter_length	|double     |	Encounter length in seconds
# described_encounter_length	|character |	Encounter length as described (eg 1 hour, etc
# description	|character          |	Description of encounter
# date_documented	|character      |	Date documented
# latitude	|double             |	Latitude
# longitude	|double             |	Longitude

# %% [markdown]
# ## Read the dataset and store it in a dataframe called `ufo`
#
# Pay attention at the file separator.

# %%
# !pwd
# Out:
# /Users/edlapaniguel/Desktop/ironhack/2.Modulo_1/Semana_04/Data-Manipulation

# %%
path = '/Users/edlapaniguel/Desktop/ironhack/2.Modulo_1/Semana_04/Data-Manipulation'

# %%
#usei o ; na tentativa e erra mesmo, caso contrario nao abria o doc
ufo = pd.read_csv(path+ '/ufo.csv', sep=';')
ufo.head()
# Out:
#    Unnamed: 0        date  year  month  day         date_time  \
# 0           0  1949-10-10  1949     10   10  10/10/1949 20:30
# 1           1  1949-10-10  1949     10   10  10/10/1949 21:00
# 2           2  1955-10-10  1955     10   10  10/10/1955 17:00
# 3           3  1956-10-10  1956     10   10  10/10/1956 21:00
# 4           4  1960-10-10  1960     10   10  10/10/1960 20:00
#
#               city_area state country ufo_shape  encounter_length  \
# 0            san marcos    tx      us  cylinder            2700.0
# 1          lackland afb    tx     NaN     light            7200.0
# 2  chester (uk/england)   NaN      gb    circle              20.0
# 3                  edna    tx      us    circle              20.0
# 4               kaneohe    hi      us     light             900.0
#
#   described_encounter_length  \
# 0                 45 minutes
# 1                    1-2 hrs
# 2                 20 seconds
# 3                   1/2 hour
# 4                 15 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2  Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3  My older brother and twin sister were leaving ...       1/17/2004
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
#
#     latitude   longitude
# 0  29.883056  -97.941111
# 1  29.384210  -98.581082
# 2  53.200000   -2.916667
# 3  28.978333  -96.645833
# 4  21.418056 -157.803611

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   date                        80332 non-null  object
#  1   year                        80332 non-null  int64
#  2   month                       80332 non-null  int64
#  3   day                         80332 non-null  int64
#  4   date_time                   80332 non-null  object
#  5   city_area                   80332 non-null  object
#  6   state                       74535 non-null  object
#  7   country                     70662 non-null  object
#  8   ufo_shape                   78400 non-null  object
#  9   encounter_length            80329 non-null  float64
#  10  described_encounter_length  80332 non-null  object
#  11  description                 80317 non-null  object
#  12  date_documented             80332 non-null  object
#  13  latitude                    80331 non-null  float64
#  14  longitude                   80332 non-null  float64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 9.2+ MB

# %% [markdown]
# ## Check the first 6 columns of the dataframe

# %%
ufo.head(6)
# Out:
#    Unnamed: 0        date  year  month  day         date_time  \
# 0           0  1949-10-10  1949     10   10  10/10/1949 20:30
# 1           1  1949-10-10  1949     10   10  10/10/1949 21:00
# 2           2  1955-10-10  1955     10   10  10/10/1955 17:00
# 3           3  1956-10-10  1956     10   10  10/10/1956 21:00
# 4           4  1960-10-10  1960     10   10  10/10/1960 20:00
# 5           5  1961-10-10  1961     10   10  10/10/1961 19:00
#
#               city_area state country ufo_shape  encounter_length  \
# 0            san marcos    tx      us  cylinder            2700.0
# 1          lackland afb    tx     NaN     light            7200.0
# 2  chester (uk/england)   NaN      gb    circle              20.0
# 3                  edna    tx      us    circle              20.0
# 4               kaneohe    hi      us     light             900.0
# 5               bristol    tn      us    sphere             300.0
#
#   described_encounter_length  \
# 0                 45 minutes
# 1                    1-2 hrs
# 2                 20 seconds
# 3                   1/2 hour
# 4                 15 minutes
# 5                  5 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2  Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3  My older brother and twin sister were leaving ...       1/17/2004
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
# 5  My father is now 89 my brother 52 the girl wit...       4/27/2007
#
#     latitude   longitude
# 0  29.883056  -97.941111
# 1  29.384210  -98.581082
# 2  53.200000   -2.916667
# 3  28.978333  -96.645833
# 4  21.418056 -157.803611
# 5  36.595000  -82.188889

# %% [markdown]
# ## Check the shape of your dataframe to see how many rows and columns it has

# %%
ufo.shape
# Out:
# (80332, 16)

# %% [markdown]
# ## Bring the date information to the beginning of the dataframe
#
# If you check the dataframe columns, there are some information of the date at the end of the dataframe. For this task, you should reorder the columns in a way that the first few columns all show the date information.
#
# *Hint: Use the ufo.columns to see all the column names you have.

# %%
ufo.columns
# Out:
# Index(['Unnamed: 0', 'date', 'year', 'month', 'day', 'date_time', 'city_area',
#        'state', 'country', 'ufo_shape', 'encounter_length',
#        'described_encounter_length', 'description', 'date_documented',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
ufo = ufo[['date', 'year', 'month', 'day', 'date_time', 'city_area',
       'state', 'country', 'ufo_shape', 'encounter_length',
       'described_encounter_length', 'description', 'date_documented',
       'latitude', 'longitude']]

# %% [markdown]
# ## Just check if you did it the right way. Take a look at the head of the dataframe again and see if the `ufo` dataframe now is reordered.

# %%
ufo.head()
# Out:
#          date  year  month  day         date_time             city_area state  \
# 0  1949-10-10  1949     10   10  10/10/1949 20:30            san marcos    tx
# 1  1949-10-10  1949     10   10  10/10/1949 21:00          lackland afb    tx
# 2  1955-10-10  1955     10   10  10/10/1955 17:00  chester (uk/england)   NaN
# 3  1956-10-10  1956     10   10  10/10/1956 21:00                  edna    tx
# 4  1960-10-10  1960     10   10  10/10/1960 20:00               kaneohe    hi
#
#   country ufo_shape  encounter_length described_encounter_length  \
# 0      us  cylinder            2700.0                 45 minutes
# 1     NaN     light            7200.0                    1-2 hrs
# 2      gb    circle              20.0                 20 seconds
# 3      us    circle              20.0                   1/2 hour
# 4      us     light             900.0                 15 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2  Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3  My older brother and twin sister were leaving ...       1/17/2004
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
#
#     latitude   longitude
# 0  29.883056  -97.941111
# 1  29.384210  -98.581082
# 2  53.200000   -2.916667
# 3  28.978333  -96.645833
# 4  21.418056 -157.803611

# %% [markdown]
# ## Select a piece of your dataframe. Create a new dataframe called `ufo_vars` and select only the following columns of the `ufo` dataframe.
#
# `year`, `month`, `state`, `country`, `ufo_shape`, `encounter_length`

# %%
ufo_vars = ufo[['year', 'month', 'state', 'country', 'ufo_shape', 'encounter_length']]

# %% [markdown]
# Perform a *.head()* on your result to check if you did it right.

# %%
ufo_vars.head()
# Out:
#    year  month state country ufo_shape  encounter_length
# 0  1949     10    tx      us  cylinder            2700.0
# 1  1949     10    tx     NaN     light            7200.0
# 2  1955     10   NaN      gb    circle              20.0
# 3  1956     10    tx      us    circle              20.0
# 4  1960     10    hi      us     light             900.0

# %% [markdown]
# ## Rename the variable `encounter_length` to `encounter_seconds`. Keep using the `ufo_vars` dataset for the following tasks, unless specifically specified.
#
# Again, check your results to check if you did it right.

# %%
ufo_vars = ufo_vars.rename(columns={'encounter_length': 'encounter_seconds'})
ufo_vars.head()
# Out:
#      year  month state country ufo_shape  encounter_seconds
# 102  2001     10    ia      us  triangle              240.0
# 108  2001     10    az      us  triangle               60.0
# 109  2001     10    va      us  triangle               30.0
# 127  2004     10    nj      us  triangle              180.0
# 147  2005     10    pa      us  triangle              300.0

# %% [markdown]
# ## Let's start filtering some records. Create a new dataframe called `ufo_us` and filter the `ufo_vars` dataframe bringing only the results in which the `country` is `"us"`

# %% [markdown]
# ### Use a mask to perform this task
#
# A `mask` is nothing more than a condition. This condition is applied to your whole dataframe (or pandas Series).
# So for example, if you had a pandas Series with a variable called `Age`, you could create a mask for all people whose `Age` is less than 18 years old using the syntax:
#
# `df['Age'] <= 18`
#
# This would return a pandas series containing `True` and `False` values. For each index, you'd get a value of `True` or `False`.
#
# You could save this mask in a variable, for example:
#
# `condition = (df['Age'] <= 18)`
#
# And then you could use that variable `condition` to select only the cases of the dataframe in which the index returned `True` using:
# df[condition].

# %%
#new dataframe called ufo_us and filter the ufo_vars bringing only  country is "us"
#filtered = data[(data['Make']=='Ford')

ufo_us = ufo_vars[ufo_vars['country'] == 'us']
ufo_us.head()
# Out:
#      year  month state country ufo_shape  encounter_seconds
# 102  2001     10    ia      us  triangle              240.0
# 108  2001     10    az      us  triangle               60.0
# 109  2001     10    va      us  triangle               30.0
# 127  2004     10    nj      us  triangle              180.0
# 147  2005     10    pa      us  triangle              300.0

# %% [markdown]
# ### Use the .query() method to perform the same task
#
# Remember that the .query() method expects a string. That string should contain the variable of your dataframe without quotation marks and the comparison. For example, if you had a variable called `name`, you'd use a syntax like:
#  `df.query('name == "Jack"')`
#
# to bring all observations whose column `name` is exactly equal to `"Jack"` (note that Jack should be within quotation marks because a name is a string in this example).

# %%
#filtered = data.query('Make == "Ford"')

ufo_us = ufo_vars.query('country == "us"')
ufo_us.head()
# Out:
#      year  month state country ufo_shape  encounter_seconds
# 102  2001     10    ia      us  triangle              240.0
# 108  2001     10    az      us  triangle               60.0
# 109  2001     10    va      us  triangle               30.0
# 127  2004     10    nj      us  triangle              180.0
# 147  2005     10    pa      us  triangle              300.0

# %% [markdown]
# See which one do you prefer the most keep using it for the exercises that follow

# %% [markdown]
# ## For the `ufo_us` dataframe, select only the cases in which the year is in the first decade (2001-2010). Put that in a variable called `ufo_us_2000`.
#
# Check your results.

# %%
#filtered = data[(data['Make']=='Ford') & (data['Cylinders']>=6) & (data['Combined MPG'] < 18)]
#filtered = data.query('Make == "Ford" and Cylinders >= 6 and `Combined MPG` < 18')
#ufo_us_2000 = ufo_us.query('year > 2000 and year <= 2010')

#ufo_us = ufo_vars[ufo_vars['country'] == 'us']
ufo_us_2000 = ufo_vars[(ufo_vars['year'] > 2000) & (ufo_vars['year'] <= 2010)]
ufo_us_2000.head()
# Out:
#      year  month state country  ufo_shape  encounter_seconds
# 102  2001     10    ia      us   triangle              240.0
# 103  2001     10   NaN      au  formation              180.0
# 104  2001     10    bc      ca      other              300.0
# 105  2001     10    ca      us     circle              120.0
# 106  2001     10    ia      us  rectangle              300.0

# %% [markdown]
# ## Try to do the same without the intermediate step of creating the `ufo_us` dataframe. That is, try to filter the dataset for the cases in which the country is "us" and the year is (2001-2010)
#
#
#
# *Hint:* You have to make sure all of these conditions are applied simultaneously - using the `and` (or `&`) operator. Try to understand when to use the `and` and the `&` operator.

# %%
#ufo_vars.query('country == "us" and year > 2000 and year <= 2010')
#filtered = data[(data['Make']=='Ford') & (data['Cylinders']>=6) & (data['Combined MPG'] < 18)]
ufo_vars = ufo_vars[(ufo_vars['country'] == 'us') & (ufo_vars['year'] > 2000) & (ufo_vars['year'] <= 2010)]
ufo_vars.head()
# Out:
#      year  month state country ufo_shape  encounter_seconds
# 102  2001     10    ia      us  triangle              240.0
# 108  2001     10    az      us  triangle               60.0
# 109  2001     10    va      us  triangle               30.0
# 127  2004     10    nj      us  triangle              180.0
# 147  2005     10    pa      us  triangle              300.0

# %% [markdown]
# ## BONUS 1:  Compare the number of triangular UFO occurrances (checking the `ufo_shape` variable) in the US from the year 2001 up to 2010 as compared to the years of 1991 up to 2000.
#
# *Hint: you should expect roughly 3 times more cases for 2001-2010 than 1991-2000.*

# %%
ufo_vars.query('year > 2000 and year <= 2010 and country == "us" and ufo_shape == "triangle"')
# Out:
#        year  month state country ufo_shape  encounter_length
# 102    2001     10    ia      us  triangle            240.00
# 108    2001     10    az      us  triangle             60.00
# 109    2001     10    va      us  triangle             30.00
# 127    2004     10    nj      us  triangle            180.00
# 147    2005     10    pa      us  triangle            300.00
# 155    2006     10    ca      us  triangle            600.00
# 158    2006     10    va      us  triangle            600.00
# 170    2007     10    ny      us  triangle          10800.00
# 183    2007     10    co      us  triangle             15.00
# 191    2008     10    ca      us  triangle             60.00
# 192    2008     10    az      us  triangle            900.00
# 221    2010     10    or      us  triangle            120.00
# 330    2001     10    ca      us  triangle             60.00
# 347    2004     10    hi      us  triangle              3.00
# 370    2005     10    az      us  triangle              3.00
# 387    2006     10    tx      us  triangle             60.00
# 393    2007     10    wa      us  triangle             10.00
# 405    2008     10    fl      us  triangle             30.00
# 409    2008     10    ca      us  triangle             30.00
# 414    2009     10    mi      us  triangle             20.00
# 428    2010     10    ca      us  triangle              5.00
# 687    2001     10    mi      us  triangle            300.00
# 701    2002     10    co      us  triangle             15.00
# 741    2004     10    va      us  triangle            300.00
# 763    2005     10    il      us  triangle           1800.00
# 764    2005     10    il      us  triangle            900.00
# 771    2005     10    il      us  triangle             10.00
# 784    2005     10    mn      us  triangle           1020.00
# 860    2007     10    nc      us  triangle              5.00
# 866    2007     10    fl      us  triangle            120.00
# 868    2008     10    ar      us  triangle            600.00
# 891    2008     10    in      us  triangle              4.00
# 894    2008     10    tn      us  triangle              3.00
# 898    2009     10    mi      us  triangle           3600.00
# 904    2009     10    ms      us  triangle            120.00
# 917    2010     10    oh      us  triangle            600.00
# 1054   2002     10    tx      us  triangle            300.00
# 1056   2002     10    tx      us  triangle            300.00
# 1080   2004     10    ca      us  triangle           3600.00
# 1090   2005     10    az      us  triangle            240.00
# 1098   2006     10    co      us  triangle             10.00
# 1099   2007     10    ut      us  triangle             10.00
# 1111   2007     10    pa      us  triangle              3.00
# 1131   2010     10    tx      us  triangle            180.00
# 1270   2001     10    ny      us  triangle           2700.00
# 1273   2001     10    az      us  triangle            120.00
# 1275   2001     10    ca      us  triangle            120.00
# 1277   2002     10    fl      us  triangle           1200.00
# 1284   2002     10    nj      us  triangle             60.00
# 1287   2003     10    co      us  triangle           1020.00
# 1317   2004     10    ar      us  triangle            300.00
# 1340   2006     10    wy      us  triangle             30.00
# 1341   2006     10    tx      us  triangle             20.00
# 1343   2006     10    ks      us  triangle             10.00
# 1348   2007     10    tx      us  triangle              5.00
# 1373   2009     10    mn      us  triangle            180.00
# 1390   2010     10    sc      us  triangle            300.00
# 1524   2002     10    mn      us  triangle             10.00
# 1525   2002     10    ut      us  triangle              2.00
# 1562   2003     10    pa      us  triangle             60.00
# 1564   2003     10    ca      us  triangle             30.00
# 1584   2005     10    mn      us  triangle           1200.00
# 1606   2007     10    nj      us  triangle            300.00
# 1632   2010     10    ca      us  triangle            480.00
# 2022   2001     10    tn      us  triangle            120.00
# 2028   2001     10    ny      us  triangle            165.00
# 2032   2001     10    nc      us  triangle            120.00
# 2035   2001     10    sd      us  triangle             30.00
# 2051   2002     10    mo      us  triangle            300.00
# 2064   2002     10    ca      us  triangle            900.00
# 2065   2002     10    ca      us  triangle             30.00
# 2069   2003     10    ca      us  triangle            240.00
# 2098   2004     10    ca      us  triangle            180.00
# 2100   2004     10    ma      us  triangle             25.00
# 2121   2005     10    id      us  triangle           1500.00
# 2158   2006     10    ne      us  triangle            300.00
# 2174   2008     10    nc      us  triangle              4.00
# 2186   2008     10    tn      us  triangle             10.00
# 2187   2008     10    tn      us  triangle              5.00
# 2199   2009     10    fl      us  triangle            360.00
# 2313   2001     10    wi      us  triangle            300.00
# 2314   2001     10    wi      us  triangle            300.00
# 2327   2002     10    oh      us  triangle            600.00
# 2362   2005     10    co      us  triangle            120.00
# 2363   2005     10    sc      us  triangle            120.00
# 2384   2007     10    ny      us  triangle             10.00
# 2396   2009     10    fl      us  triangle           1800.00
# 2401   2009     10    ca      us  triangle            120.00
# 2406   2009     10    az      us  triangle          10800.00
# 2409   2009     10    tx      us  triangle             10.00
# 2526   2001     10    fl      us  triangle              5.00
# 2542   2003     10    fl      us  triangle            120.00
# 2544   2003     10    al      us  triangle            900.00
# 2549   2003     10    nv      us  triangle            120.00
# 2584   2007     10    nj      us  triangle              7.00
# 2587   2007     10    ca      us  triangle              3.00
# 2606   2009     10    ca      us  triangle            120.00
# 2618   2009     10    co      us  triangle             10.00
# 2619   2009     10    fl      us  triangle              8.00
# 2760   2004     10    ok      us  triangle            180.00
# 2780   2006     10    il      us  triangle             15.00
# 2781   2006     10    mi      us  triangle            180.00
# 2809   2010     10    ok      us  triangle              3.00
# 2810   2010     10    ny      us  triangle             60.00
# 2816   2010     10    ga      us  triangle            300.00
# 2917   2001     10    wa      us  triangle             25.00
# 2918   2001     10    az      us  triangle             15.00
# 2921   2002     10    ia      us  triangle              5.00
# 2928   2003     10    mn      us  triangle            600.00
# 2938   2003     10    me      us  triangle            900.00
# 2944   2005     10    la      us  triangle           2700.00
# 2947   2005     10    ky      us  triangle            300.00
# 2948   2005     10    wi      us  triangle            300.00
# 2953   2006     10    co      us  triangle             60.00
# 2972   2008     10    nd      us  triangle           7200.00
# 3173   2001     10    fl      us  triangle             30.00
# 3224   2004     10    co      us  triangle             10.00
# 3231   2005     10    tx      us  triangle             30.00
# 3239   2005     10    fl      us  triangle             60.00
# 3244   2005     10    il      us  triangle            120.00
# 3270   2007     10    wv      us  triangle            420.00
# 3276   2007     10    il      us  triangle            120.00
# 3277   2007     10    mo      us  triangle            120.00
# 3292   2008     10    va      us  triangle             15.00
# 3300   2009     10    ct      us  triangle          10800.00
# 3320   2010     10    in      us  triangle            600.00
# 3321   2010     10    ms      us  triangle             90.00
# 3441   2003     10    ny      us  triangle             30.00
# 3443   2003     10    mi      us  triangle            180.00
# 3457   2004     10    tx      us  triangle             30.00
# 3466   2006     10    wa      us  triangle             30.00
# 3512   2010     10    sc      us  triangle             60.00
# 3623   2001     10    pa      us  triangle            420.00
# 3635   2003     10    co      us  triangle            300.00
# 3641   2004     10    tn      us  triangle            600.00
# 3651   2004     10    ma      us  triangle             60.00
# 3662   2005     10    nj      us  triangle            300.00
# 3680   2007     10    az      us  triangle            120.00
# 3684   2007     10    co      us  triangle           1200.00
# 3693   2008     10    ia      us  triangle              5.00
# 3695   2008     10    tx      us  triangle            120.00
# 3697   2008     10    ny      us  triangle            120.00
# 3708   2010     10    il      us  triangle             20.00
# 3800   2001     10    wi      us  triangle              7.00
# 3844   2005     10    oh      us  triangle             20.00
# 3861   2007     10    mo      us  triangle            300.00
# 3862   2007     10    mn      us  triangle              5.00
# 3867   2007     10    nj      us  triangle            300.00
# 3890   2010     10    mn      us  triangle            600.00
# 3898   2010     10    nh      us  triangle              2.00
# 4016   2002     10    ny      us  triangle            900.00
# 4030   2003     10    fl      us  triangle            300.00
# 4048   2005     10    nc      us  triangle            120.00
# 4059   2006     10    fl      us  triangle            180.00
# 4064   2006     10    ca      us  triangle             10.00
# 4066   2007     10    ks      us  triangle             20.00
# 4071   2007     10    ny      us  triangle             20.00
# 4114   2010     10    me      us  triangle            120.00
# 4117   2010     10    ma      us  triangle            180.00
# 4241   2002     10    ct      us  triangle             60.00
# 4245   2003     10    tx      us  triangle           7200.00
# 4255   2003     10    al      us  triangle             60.00
# 4256   2004     10    il      us  triangle            120.00
# 4262   2004     10    wa      us  triangle           1200.00
# 4285   2005     10    az      us  triangle            300.00
# 4286   2005     10    fl      us  triangle            600.00
# 4293   2006     10    ia      us  triangle             30.00
# 4297   2007     10    tx      us  triangle              6.00
# 4318   2008     10    va      us  triangle             60.00
# 4333   2009     10    in      us  triangle              7.00
# 4475   2001     10    az      us  triangle              4.00
# 4476   2001     10    az      us  triangle              4.00
# 4484   2003     10    ca      us  triangle            300.00
# 4485   2003     10    or      us  triangle              5.00
# 4486   2003     10    co      us  triangle             15.00
# 4492   2004     10    az      us  triangle           1200.00
# 4504   2005     10    wi      us  triangle            120.00
# 4521   2006     10    ri      us  triangle             10.00
# 4522   2007     10    oh      us  triangle             30.00
# 4530   2007     10    mi      us  triangle            420.00
# 4541   2008     10    il      us  triangle              2.00
# 4548   2008     10    oh      us  triangle             60.00
# 4562   2009     10    ca      us  triangle             60.00
# 4566   2010     10    il      us  triangle             60.00
# 4691   2003     10    ca      us  triangle             10.00
# 4698   2003     10    pa      us  triangle             60.00
# 4713   2005     10    ga      us  triangle            900.00
# 4718   2005     10    ca      us  triangle            240.00
# 4725   2006     10    ca      us  triangle             60.00
# 4727   2006     10    pa      us  triangle            300.00
# 4750   2008     10    az      us  triangle           1800.00
# 4754   2008     10    or      us  triangle             10.00
# 4757   2008     10    mo      us  triangle          37800.00
# 4759   2009     10    nh      us  triangle           1200.00
# 4761   2009     10    oh      us  triangle            120.00
# 4771   2010     10    sc      us  triangle            120.00
# 4845   2001     10    oh      us  triangle            600.00
# 4857   2003     10    ar      us  triangle           1800.00
# 4867   2004     10    ny      us  triangle             15.00
# 4869   2004     10    fl      us  triangle             60.00
# 4871   2004     10    fl      us  triangle              4.00
# 4873   2004     10    ny      us  triangle             60.00
# 4875   2004     10    ny      us  triangle              4.00
# 4879   2005     10    ia      us  triangle          18000.00
# 4887   2006     10    ks      us  triangle              6.00
# 4888   2006     10    ks      us  triangle              7.00
# 4890   2006     10    az      us  triangle              2.00
# 4929   2010     10    ny      us  triangle           1800.00
# 5052   2004     10    ny      us  triangle            900.00
# 5067   2005     10    tx      us  triangle            600.00
# 5076   2005     10    mo      us  triangle           1200.00
# 5079   2006     10    ks      us  triangle              6.00
# 5080   2006     10    ks      us  triangle              6.00
# 5083   2006     10    wi      us  triangle             30.00
# 5094   2007     10    ks      us  triangle             20.00
# 5119   2008     10    nc      us  triangle            180.00
# 5134   2008     10    tx      us  triangle             30.00
# 5143   2009     10    ca      us  triangle             60.00
# 5266   2003     10    ar      us  triangle             60.00
# 5277   2004     10    mo      us  triangle            300.00
# 5305   2007     10    mi      us  triangle            300.00
# 5312   2007     10    ny      us  triangle              5.00
# 5316   2008     10    ma      us  triangle           7200.00
# 5318   2008     10    az      us  triangle           1800.00
# 5319   2008     10    ca      us  triangle             10.00
# 5323   2008     10    oh      us  triangle            300.00
# 5326   2008     10    ar      us  triangle            300.00
# 5331   2008     10    nh      us  triangle            180.00
# 5359   2010     10    il      us  triangle              5.00
# 5364   2010     10    wa      us  triangle             15.00
# 5366   2010     10    mn      us  triangle              1.50
# 5466   2002     10    ca      us  triangle              4.00
# 5481   2003     10    mo      us  triangle             30.00
# 5482   2003     10    or      us  triangle              5.00
# 5495   2005     10    az      us  triangle             60.00
# 5510   2005     10    md      us  triangle           1500.00
# 5524   2006     10    sd      us  triangle             10.00
# 5529   2007     10    pa      us  triangle            600.00
# 5536   2007     10    az      us  triangle           1200.00
# 5538   2007     10    tx      us  triangle            120.00
# 5540   2008     10    va      us  triangle              6.00
# 5545   2008     10    ny      us  triangle             60.00
# 5549   2008     10    ca      us  triangle            300.00
# 5557   2008     10    nc      us  triangle            300.00
# 5559   2008     10    va      us  triangle              7.00
# 5563   2009     10    tx      us  triangle            300.00
# 5573   2010     10    fl      us  triangle             60.00
# 5576   2010     10    ok      us  triangle           1200.00
# 5725   2001     10    co      us  triangle             10.00
# 5727   2002     10    fl      us  triangle            300.00
# 5731   2002     10    tx      us  triangle             30.00
# 5733   2002     10    wv      us  triangle            300.00
# 5743   2003     10    wa      us  triangle              5.00
# 5749   2003     10    ri      us  triangle            120.00
# 5750   2003     10    vt      us  triangle            180.00
# 5751   2003     10    pa      us  triangle            300.00
# 5752   2003     10    az      us  triangle          28800.00
# 5754   2004     10    wi      us  triangle            600.00
# 5764   2004     10    ia      us  triangle             15.00
# 5770   2004     10    il      us  triangle           2700.00
# 5776   2004     10    il      us  triangle            900.00
# 5805   2004     10    il      us  triangle            240.00
# 5808   2004     10    il      us  triangle           1200.00
# 5815   2004     10    il      us  triangle            600.00
# 5824   2004     10    il      us  triangle           1500.00
# 5854   2005     10    az      us  triangle            600.00
# 5858   2005     10    az      us  triangle            120.00
# 5860   2005     10    ca      us  triangle             20.00
# 5880   2006     10    ca      us  triangle             10.00
# 5887   2006     10    il      us  triangle           2700.00
# 5890   2006     10    tx      us  triangle          14400.00
# 5902   2008     10    ky      us  triangle             60.00
# 5904   2008     10    tn      us  triangle            120.00
# 5915   2008     10    oh      us  triangle            120.00
# 5924   2008     10    ca      us  triangle            600.00
# 5936   2009     10    ca      us  triangle            600.00
# 5938   2009     10    ca      us  triangle            300.00
# 5941   2010     10    mi      us  triangle              5.00
# 5953   2010     10    ca      us  triangle             15.00
# 6061   2001     10    mo      us  triangle            300.00
# 6120   2007     10    nc      us  triangle            900.00
# 6121   2007     10    fl      us  triangle            300.00
# 6150   2009     10    wa      us  triangle            300.00
# 6259   2001     10    il      us  triangle            600.00
# 6275   2002     10    ca      us  triangle            120.00
# 6279   2003     10    ar      us  triangle             60.00
# 6294   2004     10    or      us  triangle            120.00
# 6298   2005     10    az      us  triangle          37800.00
# 6303   2005     10    mo      us  triangle           1800.00
# 6333   2007     10    mi      us  triangle              8.00
# 6351   2010     10    al      us  triangle            240.00
# 6355   2010     10    in      us  triangle            300.00
# 6460   2002     10    il      us  triangle            900.00
# 6469   2003     10    il      us  triangle             10.00
# 6487   2005     10    sc      us  triangle          10800.00
# 6505   2007     10    tx      us  triangle            300.00
# 6514   2007     10    ca      us  triangle            240.00
# 6534   2010     10    fl      us  triangle            180.00
# 6659   2001     10    il      us  triangle             15.00
# 6677   2003     10    md      us  triangle            120.00
# 6682   2004     10    tn      us  triangle            300.00
# 6688   2004     10    nj      us  triangle            180.00
# 6694   2004     10    pa      us  triangle             60.00
# 6704   2005     10    il      us  triangle             12.00
# 6705   2005     10    va      us  triangle             45.00
# 6712   2006     10    tx      us  triangle            300.00
# 6718   2007     10    ks      us  triangle              3.00
# 6729   2007     10    il      us  triangle          10800.00
# 6740   2008     10    oh      us  triangle            600.00
# 6743   2008     10    ct      us  triangle            900.00
# 6752   2010     10    va      us  triangle            300.00
# 6859   2001     10    mo      us  triangle              3.00
# 6872   2002     10    pa      us  triangle           1200.00
# 6874   2002     10    or      us  triangle             10.00
# 6879   2003     10    nm      us  triangle            900.00
# 6882   2003     10    il      us  triangle             45.00
# 6927   2008     10    pa      us  triangle           1200.00
# 6939   2008     10    ia      us  triangle            600.00
# 6940   2008     10    ny      us  triangle              2.00
# 6947   2009     10    nc      us  triangle            120.00
# 7032   2001     10    il      us  triangle            120.00
# 7041   2003     10    va      us  triangle            600.00
# 7073   2006     10    nc      us  triangle           5400.00
# 7102   2008     10    ca      us  triangle           2160.00
# 7116   2010     10    ak      us  triangle            900.00
# 7129   2010     10    in      us  triangle             20.00
# 7255   2004     10    ne      us  triangle            180.00
# 7257   2004     10    az      us  triangle           7200.00
# 7283   2007     10    ne      us  triangle             45.00
# 7304   2008     10    ar      us  triangle            120.00
# 7310   2009     10    ca      us  triangle           1800.00
# 7315   2009     10    nd      us  triangle            600.00
# 7324   2010     10    fl      us  triangle          21600.00
# 7330   2010     10    il      us  triangle           3600.00
# 7332   2010     10    tx      us  triangle             30.00
# 7339   2010     10    ma      us  triangle             60.00
# 7340   2010     10    pa      us  triangle           1200.00
# 7457   2001      1    wa      us  triangle            180.00
# 7530   2007      1    il      us  triangle             60.00
# 7548   2009      1    oh      us  triangle           1200.00
# 7567   2010      1    ma      us  triangle             60.00
# 7696   2003     11    nh      us  triangle            900.00
# 7709   2005     11    wa      us  triangle            120.00
# 7715   2005     11    mi      us  triangle            600.00
# 7730   2006     11    nc      us  triangle            180.00
# 7733   2006     11    fl      us  triangle             10.00
# 7739   2007     11    tx      us  triangle             30.00
# 7751   2007     11    nv      us  triangle             60.00
# 7753   2008     11    ca      us  triangle              4.00
# 7767   2009     11    al      us  triangle            120.00
# 7783   2010     11    nc      us  triangle           3600.00
# 7784   2010     11    tx      us  triangle             90.00
# 7919   2001     11    nc      us  triangle            240.00
# 7921   2001     11    ny      us  triangle            120.00
# 7932   2002     11    wi      us  triangle            180.00
# 7939   2003     11    pa      us  triangle             30.00
# 7964   2005     11    la      us  triangle            420.00
# 7966   2005     11    fl      us  triangle              1.50
# 7973   2006     11    la      us  triangle             10.00
# 7982   2006     11    mi      us  triangle            300.00
# 7996   2008     11    az      us  triangle             60.00
# 8000   2009     11    in      us  triangle             10.00
# 8242   2001     11    ny      us  triangle             15.00
# 8274   2001     11    fl      us  triangle            300.00
# 8277   2002     11    az      us  triangle            300.00
# 8296   2002     11    il      us  triangle            300.00
# 8300   2002     11    md      us  triangle             60.00
# 8305   2002     11    pr      us  triangle             30.00
# 8346   2004      1    wa      us  triangle            600.00
# 8357   2005     11    nj      us  triangle              6.00
# 8373   2005     11    il      us  triangle           3600.00
# 8381   2006     11    wa      us  triangle             60.00
# 8383   2006     11    mi      us  triangle            180.00
# 8388   2006      1    wv      us  triangle            300.00
# 8391   2007      1    il      us  triangle             10.00
# 8407   2007     11    ky      us  triangle            600.00
# 8408   2007     11    ky      us  triangle            600.00
# 8434   2008      1    tx      us  triangle              5.00
# 8437   2008     11    ut      us  triangle           1920.00
# 8444   2008     11    fl      us  triangle            420.00
# 8446   2008      1    fl      us  triangle              8.00
# 8455   2009     11    ca      us  triangle              3.00
# 8456   2009     11    va      us  triangle             90.00
# 8465   2009     11    fl      us  triangle            300.00
# 8467   2009     11    nj      us  triangle             10.00
# 8482   2010      1    mo      us  triangle             10.00
# 8684   2003     11    tx      us  triangle             60.00
# 8703   2004     11    tn      us  triangle             30.00
# 8767   2010     11    wa      us  triangle             10.00
# 8771   2010     11    me      us  triangle            300.00
# 8772   2010     11    me      us  triangle            300.00
# 8773   2010     11    me      us  triangle            300.00
# 8869   2001     11    ca      us  triangle              5.00
# 8870   2001     11    ca      us  triangle            180.00
# 8879   2002     11    ca      us  triangle            300.00
# 8884   2003     11    il      us  triangle            120.00
# 8890   2003     11    mi      us  triangle            600.00
# 8903   2004     11    ca      us  triangle            120.00
# 8918   2006     11    ca      us  triangle              5.00
# 8926   2007     11    ca      us  triangle            900.00
# 8927   2007     11    ca      us  triangle            600.00
# 8933   2007     11    ms      us  triangle            300.00
# 8944   2008     11    or      us  triangle             20.00
# 8958   2009     11    ga      us  triangle            120.00
# 9118   2001     11    tn      us  triangle            120.00
# 9122   2001     11    ma      us  triangle            300.00
# 9123   2001     11    ky      us  triangle            600.00
# 9132   2003     11    wa      us  triangle            420.00
# 9172   2007     11    ms      us  triangle             30.00
# 9173   2007     11    ca      us  triangle             10.00
# 9176   2007     11    ks      us  triangle            120.00
# 9194   2008     11    ca      us  triangle             60.00
# 9198   2009     11    nc      us  triangle             10.00
# 9217   2010     11    il      us  triangle              4.00
# 9447   2001     11    mi      us  triangle           1800.00
# 9467   2002     11    ca      us  triangle            600.00
# 9468   2002     11    mi      us  triangle            600.00
# 9491   2003     11    al      us  triangle             15.00
# 9494   2003     11    fl      us  triangle              7.00
# 9501   2004     11    ca      us  triangle             10.00
# 9503   2004     11    mt      us  triangle             70.00
# 9519   2005     11    fl      us  triangle            120.00
# 9527   2005     11    fl      us  triangle            300.00
# 9543   2005     11    va      us  triangle            120.00
# 9558   2006     11    mo      us  triangle             30.00
# 9566   2007     11    ga      us  triangle            300.00
# 9577   2008     11    nv      us  triangle             10.00
# 9584   2008     11    ca      us  triangle              7.00
# 9585   2008     11    tx      us  triangle            420.00
# 9607   2010     11    sd      us  triangle            240.00
# 9611   2010     11    ct      us  triangle            120.00
# 9901   2001     11    az      us  triangle             30.00
# 9904   2001     11    co      us  triangle              5.00
# 9905   2001     11    nc      us  triangle              5.00
# 9928   2003     11    me      us  triangle           2400.00
# 9930   2004     11    ca      us  triangle            180.00
# 9937   2004     11    ri      us  triangle            240.00
# 9941   2005     11    az      us  triangle            600.00
# 9945   2005     11    wa      us  triangle            420.00
# 9979   2008     11    ma      us  triangle            120.00
# 9996   2010     11    mi      us  triangle            180.00
# 10154  2001     11    ca      us  triangle             25.00
# 10155  2001     11    ny      us  triangle           1080.00
# 10189  2006     11    nj      us  triangle            900.00
# 10193  2006     11    wi      us  triangle            600.00
# 10198  2006     11    tx      us  triangle            600.00
# 10216  2008     11    ca      us  triangle           7200.00
# 10221  2008     11    tx      us  triangle            600.00
# 10251  2010     11    in      us  triangle              2.00
# 10252  2010     11    mt      us  triangle             60.00
# 10375  2001     11    co      us  triangle              5.00
# 10379  2001     11    wa      us  triangle             10.00
# 10382  2001     11    or      us  triangle             30.00
# 10383  2001     11    ca      us  triangle             60.00
# 10384  2001     11    ca      us  triangle             10.00
# 10385  2001     11    wa      us  triangle           3300.00
# 10400  2001     11    md      us  triangle             10.00
# 10412  2001     11    ny      us  triangle             60.00
# 10414  2001     11    co      us  triangle            240.00
# 10419  2002     11    mi      us  triangle            120.00
# 10436  2004     11    tx      us  triangle            300.00
# 10447  2005     11    ca      us  triangle             45.00
# 10459  2006     11    ca      us  triangle             10.00
# 10469  2006     11    mn      us  triangle              4.00
# 10474  2006     11    ne      us  triangle              5.00
# 10479  2007     11    ca      us  triangle            300.00
# 10483  2007     11    tx      us  triangle              6.00
# 10493  2008     11    pa      us  triangle            120.00
# 10499  2008     11    wa      us  triangle             45.00
# 10507  2009     11    fl      us  triangle              5.00
# 10622  2001     11    or      us  triangle            300.00
# 10633  2002     11    va      us  triangle             10.00
# 10636  2002     11    fl      us  triangle             20.00
# 10652  2002     11    or      us  triangle             60.00
# 10654  2003     11    ia      us  triangle            180.00
# 10655  2003     11    ia      us  triangle            180.00
# 10657  2003     11    tx      us  triangle            300.00
# 10658  2003     11    ar      us  triangle             30.00
# 10675  2003     11    mo      us  triangle             30.00
# 10676  2003     11    mo      us  triangle             30.00
# 10680  2003     11    ms      us  triangle              5.00
# 10711  2007     11    sd      us  triangle            300.00
# 10722  2008     11    ca      us  triangle            300.00
# 10730  2008     11    ca      us  triangle             60.00
# 10731  2008     11    ca      us  triangle            360.00
# 10738  2009     11    ma      us  triangle            120.00
# 10739  2009     11    az      us  triangle            600.00
# 10747  2010     11    md      us  triangle           1200.00
# 10749  2010     11    oh      us  triangle            360.00
# 10751  2010     11    mt      us  triangle            300.00
# 10978  2002      1    pa      us  triangle            300.00
# 10980  2002      1    tx      us  triangle            120.00
# 10983  2002      1    nc      us  triangle           7200.00
# 10986  2003      1    ca      us  triangle            300.00
# 10995  2003      1    me      us  triangle            600.00
# 11006  2003      1    in      us  triangle             20.00
# 11038  2005      1    az      us  triangle            600.00
# 11087  2008      1    ca      us  triangle            300.00
# 11167  2010      1    ca      us  triangle            360.00
# 11168  2010      1    ca      us  triangle            720.00
# 11170  2010      1    or      us  triangle            120.00
# 11182  2010      1    ca      us  triangle            360.00
# 11203  2010      1    ca      us  triangle            180.00
# 11204  2010      1    ma      us  triangle             30.00
# 11205  2010      1    ca      us  triangle             60.00
# 11557  2001     11    va      us  triangle            180.00
# 11579  2003     11    ne      us  triangle           1200.00
# 11583  2003     11    id      us  triangle            360.00
# 11585  2003     11    md      us  triangle           3600.00
# 11621  2007     11    nv      us  triangle            300.00
# 11748  2002     11    nc      us  triangle            300.00
# 11787  2006     11    ny      us  triangle             15.00
# 11793  2007     11    oh      us  triangle            240.00
# 11809  2008     11    ca      us  triangle              8.00
# 11818  2008     11    in      us  triangle             30.00
# 11821  2009     11    nc      us  triangle            120.00
# 11834  2010     11    or      us  triangle             30.00
# 11930  2001     11    ar      us  triangle              6.00
# 11941  2002      1    ny      us  triangle             20.00
# 11948  2002     11    ca      us  triangle            900.00
# 11949  2002     11    ca      us  triangle            900.00
# 11955  2002      1    ca      us  triangle              2.00
# 11959  2003     11    il      us  triangle           3600.00
# 11960  2003      1    mn      us  triangle            600.00
# 11964  2003     11    mn      us  triangle            420.00
# 11977  2004      1    tx      us  triangle            420.00
# 11982  2004      1    ia      us  triangle           1200.00
# 11983  2004      1    ia      us  triangle            120.00
# 11992  2005     11    ga      us  triangle             10.00
# 12000  2005      1    oh      us  triangle            900.00
# 12003  2005     11    il      us  triangle            120.00
# 12004  2005      1    ca      us  triangle           1200.00
# 12006  2005      1    ma      us  triangle            180.00
# 12014  2005     11    va      us  triangle            900.00
# 12020  2006      1    ok      us  triangle            240.00
# 12035  2007     11    nj      us  triangle             20.00
# 12048  2007     11    ut      us  triangle             60.00
# 12049  2007     11    ga      us  triangle             30.00
# 12050  2007     11    wa      us  triangle             10.00
# 12055  2008      1    pa      us  triangle            120.00
# 12060  2008      1    oh      us  triangle             75.00
# 12073  2008      1    pa      us  triangle            300.00
# 12076  2008     11    ct      us  triangle            480.00
# 12078  2008      1    ca      us  triangle             15.00
# 12081  2008     11    il      us  triangle             45.00
# 12104  2009     11    oh      us  triangle           1800.00
# 12106  2009      1    la      us  triangle            300.00
# 12124  2010     11    ca      us  triangle              6.00
# 12128  2010     11    ca      us  triangle            420.00
# 12130  2010     11    or      us  triangle              5.00
# 12285  2001     11    mi      us  triangle              5.00
# 12293  2002     11    mi      us  triangle            300.00
# 12300  2003     11    pa      us  triangle             30.00
# 12301  2003     11    al      us  triangle              4.00
# 12307  2003     11    ca      us  triangle             10.00
# 12308  2003     11    ca      us  triangle             15.00
# 12318  2003     11    co      us  triangle             30.00
# 12320  2004     11    mi      us  triangle            300.00
# 12321  2005     11    sc      us  triangle            300.00
# 12325  2005     11    mt      us  triangle             25.00
# 12346  2005     11    ga      us  triangle            300.00
# 12349  2006     11    pa      us  triangle           3600.00
# 12359  2006     11    al      us  triangle            120.00
# 12375  2008     11    mi      us  triangle             45.00
# 12394  2010     11    az      us  triangle           1200.00
# 12527  2001     11    co      us  triangle            300.00
# 12545  2003     11    nj      us  triangle            180.00
# 12559  2005     11    tx      us  triangle             15.00
# 12574  2006     11    mo      us  triangle            120.00
# 12578  2006     11    in      us  triangle             20.00
# 12589  2007     11    ia      us  triangle            180.00
# 12596  2008     11    wa      us  triangle            300.00
# 12599  2008     11    il      us  triangle            300.00
# 12619  2010     11    il      us  triangle              5.00
# 12716  2003     11    ca      us  triangle             60.00
# 12724  2003     11    ca      us  triangle             60.00
# 12737  2005     11    ca      us  triangle             15.00
# 12742  2005     11    ca      us  triangle            300.00
# 12754  2006     11    tx      us  triangle            900.00
# 12760  2006     11    mo      us  triangle            900.00
# 12774  2008     11    mo      us  triangle             90.00
# 12785  2009     11    tn      us  triangle             30.00
# 12913  2004     11    ia      us  triangle            300.00
# 12926  2005     11    fl      us  triangle             45.00
# 12972  2010     11    va      us  triangle           2400.00
# 12975  2010     11    tx      us  triangle            300.00
# 13052  2001     11    ky      us  triangle            240.00
# 13058  2002     11    ca      us  triangle           1800.00
# 13071  2003     11    az      us  triangle             90.00
# 13072  2003     11    ca      us  triangle             15.00
# 13126  2009     11    co      us  triangle              3.00
# 13135  2009     11    co      us  triangle           3600.00
# 13136  2010     11    az      us  triangle            600.00
# 13215  2001     11    mo      us  triangle             60.00
# 13217  2001     11    ga      us  triangle         361800.00
# 13220  2002     11    wa      us  triangle         109800.00
# 13224  2002     11    ca      us  triangle             60.00
# 13228  2003     11    ca      us  triangle             15.00
# 13232  2003     11    ca      us  triangle             60.00
# 13243  2004     11    tx      us  triangle          10800.00
# 13259  2006     11    wa      us  triangle            180.00
# 13262  2006     11    ky      us  triangle            300.00
# 13268  2007     11    tx      us  triangle            180.00
# 13296  2009     11    pa      us  triangle             10.00
# 13307  2010     11    md      us  triangle             60.00
# 13385  2002     11    ma      us  triangle            600.00
# 13411  2003     11    ca      us  triangle            138.00
# 13422  2005     11    nc      us  triangle            120.00
# 13482  2007     11    pa      us  triangle            180.00
# 13502  2009     11    la      us  triangle            600.00
# 13507  2009     11    il      us  triangle             10.00
# 13508  2009     11    il      us  triangle             10.00
# 13509  2009     11    il      us  triangle             15.00
# 13514  2010     11    mi      us  triangle            300.00
# 13515  2010     11    oh      us  triangle            600.00
# 13517  2010     11    ca      us  triangle             20.00
# 13638  2003     11    pa      us  triangle             60.00
# 13655  2005     11    al      us  triangle              5.00
# 13666  2006     11    il      us  triangle            300.00
# 13790  2002     11    ca      us  triangle            120.00
# 13792  2002     11    ks      us  triangle             60.00
# 13809  2003     11    tn      us  triangle            180.00
# 13830  2006     11    ar      us  triangle            180.00
# 13839  2006     11    ca      us  triangle            120.00
# 13841  2006     11    oh      us  triangle            180.00
# 13858  2009     11    az      us  triangle           1200.00
# 13860  2010     11    mo      us  triangle            240.00
# 13861  2010     11    ca      us  triangle            720.00
# 13998  2003     11    al      us  triangle             60.00
# 14002  2003     11    nc      us  triangle             30.00
# 14009  2004      1    pa      us  triangle             15.00
# 14048  2005     11    ny      us  triangle             30.00
# 14063  2005     11    ca      us  triangle            600.00
# 14069  2006     11    ny      us  triangle            240.00
# 14077  2006      1    ca      us  triangle            480.00
# 14081  2007      1    tx      us  triangle            600.00
# 14097  2007     11    nc      us  triangle              1.00
# 14100  2007      1    ca      us  triangle             10.00
# 14101  2007     11    fl      us  triangle             30.00
# 14109  2008     11    tn      us  triangle            120.00
# 14119  2008     11    az      us  triangle             40.00
# 14144  2009      1    pa      us  triangle             60.00
# 14149  2009      1    ca      us  triangle             60.00
# 14153  2010      1    pa      us  triangle             30.00
# 14167  2010     11    or      us  triangle             10.00
# 14355  2002     11    fl      us  triangle            180.00
# 14357  2002      1    or      us  triangle            120.00
# 14391  2004     11    tx      us  triangle           7200.00
# 14395  2004     11    ca      us  triangle             15.00
# 14399  2004     11    fl      us  triangle             15.00
# 14409  2005     11    wv      us  triangle            180.00
# 14420  2005     11    mt      us  triangle             15.00
# 14425  2006     11    co      us  triangle             90.00
# 14437  2006      1    nc      us  triangle            300.00
# 14450  2007     11    wy      us  triangle             10.00
# 14451  2007     11    or      us  triangle            600.00
# 14470  2007      1    fl      us  triangle              1.00
# 14480  2008      1    ca      us  triangle             45.00
# 14493  2008     11    ca      us  triangle             60.00
# 14500  2009     11    or      us  triangle            120.00
# 14505  2009      1    ca      us  triangle             60.00
# 14525  2010      1    ar      us  triangle            600.00
# 14787  2001     11    wa      us  triangle             60.00
# 14797  2002      1    fl      us  triangle            180.00
# 14801  2002      1    fl      us  triangle            360.00
# 14857  2004     11    wa      us  triangle              2.00
# 14883  2005      1    fl      us  triangle          12600.00
# 14902  2005      1    al      us  triangle            120.00
# 14906  2006      1    mo      us  triangle            120.00
# 14952  2007     11    ak      us  triangle              5.00
# 14955  2007     11    co      us  triangle            300.00
# 14959  2007     11    va      us  triangle             20.00
# 14960  2007     11    mi      us  triangle             60.00
# 14964  2008      1    oh      us  triangle            900.00
# 14965  2008      1    md      us  triangle              2.00
# 14968  2008      1    tx      us  triangle             20.00
# 14977  2008      1    nc      us  triangle            120.00
# 14986  2008     11    sc      us  triangle            240.00
# 15007  2009     11    fl      us  triangle             15.00
# 15043  2010     11    ct      us  triangle           2700.00
# 15044  2010      1    nc      us  triangle             60.00
# 15250  2003      1    nd      us  triangle           1500.00
# 15265  2004      1    nj      us  triangle            300.00
# 15277  2004     11    oh      us  triangle            120.00
# 15335  2007      1    nc      us  triangle            300.00
# 15337  2007      1    il      us  triangle           7200.00
# 15349  2008      1    ct      us  triangle            240.00
# 15350  2008      1    ok      us  triangle            240.00
# 15364  2008      1    in      us  triangle            300.00
# 15365  2008      1    in      us  triangle           2700.00
# 15366  2008     11    ca      us  triangle              6.00
# 15367  2008     11    co      us  triangle           1800.00
# 15368  2008      1    nj      us  triangle            300.00
# 15392  2009      1    ny      us  triangle            180.00
# 15404  2010      1    ca      us  triangle            300.00
# 15576  2002     11    az      us  triangle            300.00
# 15583  2002      1    or      us  triangle            600.00
# 15588  2003     11    az      us  triangle             10.00
# 15606  2003      1    fl      us  triangle            900.00
# 15616  2003      1    ca      us  triangle            600.00
# 15629  2004     11    ar      us  triangle            600.00
# 15647  2004     11    wa      us  triangle              5.00
# 15648  2004     11    wa      us  triangle             30.00
# 15667  2005     11    fl      us  triangle            480.00
# 15669  2005     11    tx      us  triangle           2700.00
# 15691  2006      1    ca      us  triangle            300.00
# 15701  2007     11    mi      us  triangle            600.00
# 15711  2007      1    pa      us  triangle             30.00
# 15714  2007      1    il      us  triangle            180.00
# 15715  2007     11    oh      us  triangle            300.00
# 15718  2007     11    ny      us  triangle             60.00
# 15723  2008      1    md      us  triangle            300.00
# 15726  2008      1    ny      us  triangle            180.00
# 15734  2008      1    md      us  triangle           1200.00
# 15735  2008      1    ca      us  triangle           1800.00
# 15751  2009      1    oh      us  triangle            300.00
# 15770  2010     11    nc      us  triangle             15.00
# 15779  2010     11    nj      us  triangle            120.00
# 15950  2002     11    mi      us  triangle           1200.00
# 15973  2003     11    ma      us  triangle             30.00
# 15981  2003     11    il      us  triangle            300.00
# 15996  2003     11    ny      us  triangle             60.00
# 16002  2003     11    ny      us  triangle            900.00
# 16004  2003     11    ny      us  triangle           6300.00
# 16007  2003     11    ny      us  triangle            300.00
# 16010  2003     11    va      us  triangle             20.00
# 16017  2004     11    mo      us  triangle            180.00
# 16020  2004     11    la      us  triangle             60.00
# 16028  2004      1    nc      us  triangle            450.00
# 16029  2004     11    wa      us  triangle            600.00
# 16056  2006     11    az      us  triangle            600.00
# 16060  2006     11    ca      us  triangle            600.00
# 16074  2006     11    co      us  triangle             15.00
# 16082  2007     11    tx      us  triangle            600.00
# 16083  2007      1    tx      us  triangle             10.00
# 16095  2008      1    ga      us  triangle            120.00
# 16117  2008      1    nc      us  triangle             20.00
# 16122  2008      1    wa      us  triangle             60.00
# 16134  2009      1    ca      us  triangle            120.00
# 16156  2009      1    ca      us  triangle             30.00
# 16159  2009     11    wv      us  triangle             90.00
# 16168  2010      1    nj      us  triangle             60.00
# 16360  2001     11    mo      us  triangle             85.00
# 16377  2002     11    ks      us  triangle             60.00
# 16387  2003     11    ca      us  triangle             30.00
# 16390  2004     11    ca      us  triangle             10.00
# 16407  2005     11    ok      us  triangle             20.00
# 16415  2005     11    ga      us  triangle            600.00
# 16430  2006      1    il      us  triangle            120.00
# 16434  2006      1    pa      us  triangle           1200.00
# 16436  2006      1    tx      us  triangle            300.00
# 16438  2006     11    ma      us  triangle            300.00
# 16453  2007      1    mo      us  triangle            300.00
# 16462  2007      1    tn      us  triangle             60.00
# 16479  2008     11    sc      us  triangle             40.00
# 16504  2009      1    pa      us  triangle            180.00
# 16510  2009     11    wa      us  triangle            120.00
# 16518  2010     11    tx      us  triangle            240.00
# 16521  2010     11    va      us  triangle           2700.00
# 16522  2010     11    tx      us  triangle              4.00
# 16710  2003      1    wa      us  triangle             20.00
# 16725  2005      1    ca      us  triangle           2700.00
# 16727  2005      1    nv      us  triangle            180.00
# 16739  2007      1    ca      us  triangle            180.00
# 16746  2007      1    in      us  triangle            300.00
# 16752  2007      1    mn      us  triangle             20.00
# 16770  2008      1    ca      us  triangle             12.00
# 16774  2008      1    al      us  triangle            720.00
# 16783  2009      1    ak      us  triangle            900.00
# 16934  2004     12    mi      us  triangle            120.00
# 16996  2007     12    ma      us  triangle            120.00
# 17007  2008     12    ny      us  triangle            120.00
# 17096  2001     12    co      us  triangle             15.00
# 17101  2002     12    wi      us  triangle            420.00
# 17106  2003     12    il      us  triangle           1200.00
# 17115  2003     12    mi      us  triangle            180.00
# 17124  2004     12    tx      us  triangle             15.00
# 17127  2004     12    tx      us  triangle             15.00
# 17128  2004     12    tx      us  triangle             20.00
# 17129  2004     12    tx      us  triangle             20.00
# 17146  2006     12    pa      us  triangle             60.00
# 17154  2007     12    fl      us  triangle            180.00
# 17160  2008     12    mi      us  triangle             60.00
# 17171  2009     12    md      us  triangle              7.00
# 17177  2010     12    nh      us  triangle            120.00
# ...
# 74926  2008      9    fl      us  triangle            120.00
# 74951  2010      9    ny      us  triangle             10.00
# 74958  2010      9    ri      us  triangle             60.00
# 75098  2003      9    or      us  triangle            600.00
# 75113  2004      9    wa      us  triangle            120.00
# 75126  2005      9    nh      us  triangle            600.00
# 75142  2007      9    co      us  triangle              9.00
# 75146  2007      9    ms      us  triangle              5.00
# 75153  2007      9    ca      us  triangle            900.00
# 75271  2001      9    fl      us  triangle              5.00
# 75283  2003      9    fl      us  triangle            600.00
# 75292  2003      9    fl      us  triangle            900.00
# 75302  2004      9    tx      us  triangle             30.00
# 75303  2004      9    ca      us  triangle            180.00
# 75305  2004      9    ca      us  triangle            600.00
# 75315  2005      9    de      us  triangle             60.00
# 75337  2007      9    ca      us  triangle            120.00
# 75343  2007      9    ca      us  triangle             30.00
# 75365  2008      9    oh      us  triangle            300.00
# 75377  2009      9    wa      us  triangle             10.00
# 75378  2009      9    ca      us  triangle            300.00
# 75384  2009      9    ny      us  triangle             15.00
# 75387  2010      9    co      us  triangle             30.00
# 75400  2010      9    il      us  triangle            900.00
# 75401  2010      9    tx      us  triangle             15.00
# 75525  2004      9    nj      us  triangle             60.00
# 75532  2004      9    wa      us  triangle            120.00
# 75542  2005      9    wa      us  triangle           1200.00
# 75561  2007      9    nc      us  triangle             10.00
# 75563  2007      9    ca      us  triangle             60.00
# 75564  2008      9    ca      us  triangle           3600.00
# 75589  2009      9    mo      us  triangle            300.00
# 75611  2010      9    ky      us  triangle           3600.00
# 75706  2001      9    ok      us  triangle            300.00
# 75707  2001      9    ok      us  triangle            300.00
# 75714  2002      9    ca      us  triangle           3600.00
# 75715  2002      9    mo      us  triangle           3600.00
# 75760  2003      9    nj      us  triangle             30.00
# 75763  2003      9    ks      us  triangle             20.00
# 75791  2005      9    oh      us  triangle             20.00
# 75810  2008      9    il      us  triangle            900.00
# 75826  2009      9    wa      us  triangle            180.00
# 75827  2009      9    me      us  triangle            300.00
# 75842  2009      9    md      us  triangle             30.00
# 75847  2009      9    me      us  triangle             20.00
# 75850  2009      9    pa      us  triangle             15.00
# 75915  2009      9    ri      us  triangle             60.00
# 76078  2002      9    mn      us  triangle              6.00
# 76091  2003      9    ma      us  triangle              1.00
# 76116  2004      9    sc      us  triangle             60.00
# 76117  2004      9    wa      us  triangle            120.00
# 76140  2005      9    il      us  triangle             20.00
# 76145  2006      9    fl      us  triangle             12.00
# 76159  2007      9    il      us  triangle            240.00
# 76162  2007      9    nm      us  triangle            120.00
# 76175  2008      9    fl      us  triangle             30.00
# 76192  2009      9    tx      us  triangle             60.00
# 76318  2001      9    ga      us  triangle              2.00
# 76330  2002      9    ok      us  triangle           1800.00
# 76342  2003      9    il      us  triangle            120.00
# 76382  2006      9    fl      us  triangle              1.00
# 76405  2007      9    oh      us  triangle            180.00
# 76406  2007      9    oh      us  triangle           1500.00
# 76407  2007      9    oh      us  triangle            600.00
# 76408  2007      9    oh      us  triangle            900.00
# 76410  2007      9    ca      us  triangle            420.00
# 76432  2009      9    wa      us  triangle             10.00
# 76607  2003      9    wa      us  triangle             20.00
# 76670  2007      9    co      us  triangle            120.00
# 76677  2007      9    ca      us  triangle             40.00
# 76697  2008      9    wa      us  triangle            120.00
# 76717  2010      9    pa      us  triangle           3600.00
# 76856  2001      9    co      us  triangle          10800.00
# 76872  2003      9    il      us  triangle              3.00
# 76877  2003      9    me      us  triangle            240.00
# 76900  2005      9    tx      us  triangle            180.00
# 76924  2005      9    ca      us  triangle            120.00
# 76935  2006      9    tx      us  triangle             90.00
# 76946  2006      9    ca      us  triangle            120.00
# 76948  2006      9    ma      us  triangle            300.00
# 76949  2006      9    tx      us  triangle           1500.00
# 76967  2007      9    oh      us  triangle          10800.00
# 76990  2008      9    ga      us  triangle              3.00
# 77003  2010      9    mi      us  triangle            600.00
# 77157  2001      9    wa      us  triangle           1800.00
# 77158  2001      9    wa      us  triangle           1800.00
# 77159  2001      9    wa      us  triangle            600.00
# 77170  2002      9    ca      us  triangle           4500.00
# 77174  2003      9    co      us  triangle              5.00
# 77175  2003      9    co      us  triangle             15.00
# 77192  2003      9    mn      us  triangle              5.00
# 77202  2005      9    wv      us  triangle            300.00
# 77214  2006      9    ut      us  triangle             10.00
# 77225  2007      9    ct      us  triangle            600.00
# 77228  2008      9    ca      us  triangle             25.00
# 77234  2008      9    nv      us  triangle             35.00
# 77235  2008      9    mn      us  triangle            120.00
# 77237  2008      9    fl      us  triangle             30.00
# 77240  2008      9    mi      us  triangle             24.00
# 77363  2002      9    il      us  triangle             45.00
# 77368  2003      9    tn      us  triangle             90.00
# 77371  2003      9    ny      us  triangle            255.00
# 77378  2003      9    fl      us  triangle            120.00
# 77383  2003      9    ut      us  triangle             30.00
# 77403  2005      9    fl      us  triangle             30.00
# 77430  2008      9    ca      us  triangle           3600.00
# 77547  2001      9    az      us  triangle             15.00
# 77553  2001      9    in      us  triangle            900.00
# 77580  2003      9    ca      us  triangle            420.00
# 77586  2004      9    co      us  triangle             30.00
# 77610  2006      9    nh      us  triangle           1200.00
# 77611  2006      9    wa      us  triangle             10.00
# 77613  2006      9    az      us  triangle            180.00
# 77623  2007      9    tn      us  triangle            120.00
# 77625  2007      9    va      us  triangle            420.00
# 77628  2007      9    ny      us  triangle            120.00
# 77630  2008      9    vt      us  triangle            150.00
# 77632  2008      9    tx      us  triangle             30.00
# 77634  2008      9    ne      us  triangle             30.00
# 77774  2002      9    ut      us  triangle           3600.00
# 77777  2003      9    or      us  triangle              7.00
# 77779  2003      9    fl      us  triangle             15.00
# 77809  2005      9    ca      us  triangle           1500.00
# 77816  2005      9    mi      us  triangle             60.00
# 77817  2006      9    or      us  triangle             10.00
# 77821  2006      9    ca      us  triangle             20.00
# 77826  2007      9    tn      us  triangle             60.00
# 77843  2008      9    wa      us  triangle            180.00
# 77848  2008      9    wy      us  triangle              3.00
# 77975  2001      9    fl      us  triangle             60.00
# 78001  2003      9    tx      us  triangle            300.00
# 78008  2004      9    tn      us  triangle            300.00
# 78031  2007      9    nv      us  triangle             20.00
# 78033  2007      9    oh      us  triangle            120.00
# 78035  2007      9    az      us  triangle            120.00
# 78049  2008      9    ut      us  triangle              6.00
# 78160  2002      9    in      us  triangle             30.00
# 78172  2003      9    nv      us  triangle             60.00
# 78174  2003      9    ga      us  triangle             60.00
# 78175  2003      9    tn      us  triangle             10.00
# 78195  2004      9    az      us  triangle            900.00
# 78202  2005      9    fl      us  triangle            900.00
# 78219  2006      9    ct      us  triangle             60.00
# 78222  2006      9    ar      us  triangle             10.00
# 78230  2008      9    tx      us  triangle            300.00
# 78248  2009      9    wi      us  triangle            300.00
# 78401  2002      9    ga      us  triangle            300.00
# 78406  2002      9    de      us  triangle           1800.00
# 78410  2002      9    de      us  triangle            300.00
# 78411  2003      9    az      us  triangle             45.00
# 78413  2003      9    wa      us  triangle            300.00
# 78425  2004      9    ca      us  triangle           7200.00
# 78429  2004      9    tn      us  triangle          25200.00
# 78452  2006      9    ks      us  triangle            420.00
# 78467  2008      9    ca      us  triangle            300.00
# 78468  2008      9    co      us  triangle             45.00
# 78475  2008      9    ca      us  triangle            120.00
# 78479  2008      9    ca      us  triangle           1800.00
# 78487  2010      9    fl      us  triangle             90.00
# 78490  2010      9    fl      us  triangle            180.00
# 78662  2003      9    ny      us  triangle              5.00
# 78663  2003      9    ma      us  triangle             20.00
# 78674  2005      9    il      us  triangle            300.00
# 78675  2005      9    ky      us  triangle            480.00
# 78692  2005      9    co      us  triangle             20.00
# 78699  2005      9    il      us  triangle           1800.00
# 78712  2005      9    il      us  triangle           1200.00
# 78727  2005      9    il      us  triangle            900.00
# 78733  2006      9    va      us  triangle            720.00
# 78740  2006      9    nm      us  triangle           3600.00
# 78743  2007      9    ne      us  triangle            120.00
# 78756  2007      9    ga      us  triangle             90.00
# 78757  2007      9    ga      us  triangle             90.00
# 78767  2009      9    il      us  triangle           7200.00
# 78771  2010      9    tx      us  triangle             30.00
# 78772  2010      9    wa      us  triangle            600.00
# 78776  2010      9    ia      us  triangle              0.50
# 78784  2010      9    co      us  triangle              3.00
# 78788  2010      9    ky      us  triangle            180.00
# 78879  2003      9    sc      us  triangle            300.00
# 78885  2003      9    wa      us  triangle            600.00
# 78887  2003      9    tx      us  triangle             30.00
# 78899  2004      9    ct      us  triangle             20.00
# 78908  2004      9    fl      us  triangle              5.00
# 78909  2005      9    il      us  triangle             20.00
# 78912  2005      9    oh      us  triangle              9.00
# 78940  2007      9    fl      us  triangle             60.00
# 78942  2008      9    fl      us  triangle            300.00
# 78945  2008      9    tx      us  triangle             60.00
# 78970  2010      9    ca      us  triangle             20.00
# 78971  2010      9    id      us  triangle             30.00
# 78972  2010      9    id      us  triangle             10.00
# 78974  2010      9    ma      us  triangle            120.00
# 78981  2010      9    ny      us  triangle           3000.00
# 78983  2010      9    mn      us  triangle            300.00
# 79086  2002      9    tx      us  triangle            900.00
# 79109  2004      9    ca      us  triangle            180.00
# 79124  2004      9    mt      us  triangle            120.00
# 79137  2005      9    ca      us  triangle            300.00
# 79144  2007      9    ca      us  triangle           1200.00
# 79145  2007      9    ca      us  triangle             30.00
# 79153  2007      9    mo      us  triangle             10.00
# 79154  2007      9    ut      us  triangle            900.00
# 79161  2008      9    wa      us  triangle            900.00
# 79162  2008      9    ca      us  triangle             90.00
# 79166  2009      9    oh      us  triangle             60.00
# 79180  2010      9    ky      us  triangle            120.00
# 79181  2010      9    il      us  triangle             60.00
# 79195  2010      9    ky      us  triangle            120.00
# 79308  2001      9    oh      us  triangle             35.00
# 79326  2002      9    wi      us  triangle            300.00
# 79334  2003      9    az      us  triangle             60.00
# 79359  2005      9    sc      us  triangle            120.00
# 79365  2006      9    oh      us  triangle             30.00
# 79387  2009      9    de      us  triangle           2400.00
# 79408  2010      9    il      us  triangle            420.00
# 79416  2010      9    ny      us  triangle           1200.00
# 79418  2010      9    ca      us  triangle              3.00
# 79511  2001      9    ia      us  triangle            240.00
# 79527  2002      9    oh      us  triangle            600.00
# 79533  2002      9    co      us  triangle             60.00
# 79540  2002      9    ks      us  triangle             15.00
# 79543  2002      9    mi      us  triangle             60.00
# 79556  2004      9    tx      us  triangle             30.00
# 79558  2004      9    tx      us  triangle            180.00
# 79564  2004      9    ky      us  triangle          10800.00
# 79571  2005      9    in      us  triangle             60.00
# 79580  2005      9    wa      us  triangle             10.00
# 79586  2006      9    il      us  triangle            300.00
# 79595  2007      9    nh      us  triangle            300.00
# 79606  2008      9    la      us  triangle             60.00
# 79622  2010      9    nj      us  triangle           1200.00
# 79626  2010      9    tx      us  triangle            900.00
# 79633  2010      9    oh      us  triangle             40.00
# 79716  2001      9    or      us  triangle              5.00
# 79722  2002      9    wa      us  triangle             20.00
# 79737  2002      9    wa      us  triangle             20.00
# 79757  2004      9    ar      us  triangle            120.00
# 79784  2007      9    la      us  triangle             20.00
# 79785  2007      9    fl      us  triangle              8.00
# 79793  2008      9    wa      us  triangle            600.00
# 79794  2008      9    ia      us  triangle            120.00
# 79810  2009      9    or      us  triangle            300.00
# 79821  2010      9    ca      us  triangle              8.00
# 79929  2002      9    ma      us  triangle            180.00
# 79930  2002      9    oh      us  triangle            180.00
# 79931  2002      9    nv      us  triangle             10.00
# 79947  2004      9    ca      us  triangle             25.00
# 79972  2007      9    ca      us  triangle             20.00
# 79987  2008      9    pa      us  triangle           1200.00
# 80008  2009      9    fl      us  triangle              5.00
# 80025  2010      9    md      us  triangle             60.00
# 80160  2003      9    fl      us  triangle            120.00
# 80161  2003      9    fl      us  triangle            120.00
# 80164  2003      9    fl      us  triangle            300.00
# 80166  2003      9    fl      us  triangle            120.00
# 80173  2003      9    md      us  triangle            120.00
# 80195  2004      9    mi      us  triangle            240.00
# 80231  2008      9    il      us  triangle              7.00
# 80235  2009      9    co      us  triangle            900.00
# 80248  2009      9    or      us  triangle            300.00
# 80256  2009      9    mi      us  triangle            360.00

# %%
ufo_vars.query('year > 2000 and year <= 2010 and country == "us" and ufo_shape == "triangle"').shape
# Out:
# (3353, 6)

# %%
ufo_vars = ufo_vars[(ufo_vars['country'] == 'us') & (ufo_vars['year'] > 2000) & (ufo_vars['year'] <= 2010) & (ufo_vars['ufo_shape'] == 'triangle')]
ufo_vars.head()
# Out:
#      year  month state country ufo_shape  encounter_seconds
# 102  2001     10    ia      us  triangle              240.0
# 108  2001     10    az      us  triangle               60.0
# 109  2001     10    va      us  triangle               30.0
# 127  2004     10    nj      us  triangle              180.0
# 147  2005     10    pa      us  triangle              300.0

# %%
ufo_vars.query('year > 1990 and year <= 2000 and country == "us" and ufo_shape == "triangle"').shape
# Out:
# (0, 6)

# %%
#Another one bites the dust!

# %% [markdown]
# ## BONUS 1.1: How many values does each category of `ufo_shape` has.
#
# *Hint: Remember last class*

# %% [markdown]
# # Lab-Data-Manipulation (PART-2)

# %% [markdown]
# The second part of this lab consists of grouping and merging results.

# %% [markdown]
# # Grouping up the results.

# %% [markdown]
# ## Let's calculate the average of the encounter for each country.
#
# We should now group the results by the country column to see what is the mean encounter_seconds for each country. Do this using the `groupby` method of your dataframe `ufo_vars`. What is the average of the encounter for the us? And for Canada?
#
# Remember that after grouping by a column, you have to specify a `aggregating function`. If you don't do that, the results of the groupby will only be a `groupby` pandas object. For this case, we want the aggregating function to be the `mean` function and then the results will appear for us.
#
# Also remember that **if you don't** specify the `as_index=False` argument, the variables you use to group are going to become your new indexes.

# %% [markdown]
# ## Perform the same task, but instead of calculating the mean, count how many occurrances for each country.
#
# For this case, the aggregating function should be the `count` function. Try to understand the results for each column.

# %% [markdown]
# ## Perform the same task, but instead of calculating the mean, use the `.describe()` aggregating function to see the effects.
#
# The describe aggregating function will show you several important statistics for the grouped results, such as `mean`, `median`, `standard deviation`, `count`, `max`, `min`, and so on.
#
# *Hint: If it starts to get difficult to see the results, you can tranpose the resulting dataframe by just putting a `.T` at the end.*

# %% [markdown]
# ## Now, let's get deeper in the analysis and group the results not only by country. But by `country` and `year`

# %% [markdown]
# ### Check the values of the mean and count for the `encounter_seconds` variable for each year. Can you see some discrepancy?
#
# *Hint*: If you want, you can use the `ufo_us` dataset just to see the results for the united states. You could also (in a hacky way) perform the filter right before the groupby operation if you wanted.

# %% [markdown]
# # BONUS 2: Which months are the ones with the highest numbers of occurrences?
#
# Use the groupby function to `count` the number of ocurrences using the `month` variable as `key` for the groupby. Which are the months that UFOs appears the most?
#
# *hint: The best way to visualize is to select the key and a single variable, for example ['month','year'] to check the results*

# %% [markdown]
# # BONUS 3: Finally, you gathered information about the UFO dataset. Using your last result, try to bring that information for your original dataset.

# %% [markdown]
# 1. Store the results of your previous analysis (the mean value for the encounter_seconds for each year and each country) in a dataframe called `avg_results`. Remeber, in this case, to pass the argument `as_index=False` to your groupby method to keep the `keys` as columns.

# %% [markdown]
# 2. Rename the column named `encounter_seconds` to `avg_encounter_seconds`.

# %% [markdown]
# 3. Use the pd.merge( ... ) function to bring that new collected information to your original dataset.
# The pd.merge() function requires several arguments, let's understand the most important ones.
#
# `left` is the dataframe you want to bring information **to** - the table on the left. In this case, this will be our original dataframe called `ufo`
#
# `right` is the dataframe you want to bring information **from** - the table on the right. In this case, this will be our resulting dataframe `avg_results`.
#
# `on` is the key you want to perform the merge. That is, if those values are **exactly equal** in both dataframes, then the information will be brought.
#
# Put your results on a dataframe called `merged_ufo`

# %% [markdown]
# Check how many rows the final result has and try to explain it. Did the dataset get smaller? Bigger? Or the same? Can you explain why?
#
# *hint: This has to do with the `how` argument you *used* (or rather its default value) in pd.merge() method.*

# %% [markdown]
# ## Store the results into a new csv file called `ufo_enriched.csv`.
#
# Don't forget to use `index=False`.
